# %%
import requests
import shutil

from PIL import Image

'''
Looks like you have to change the three numbers to get specific spots
https://tile5.navionics.com/tile/16/18696/25103
'''
# Out:
# '\nLooks like you have to change the three numbers to get specific spots\nhttps://tile5.navionics.com/tile/16/18696/25103\n'

# %%
def _test_params(p1,p2,p3, img_filename = 'img.jpg'):
    url = f'https://tile5.navionics.com/tile/{p1}/{p2}/{p3}?LAYERS=config_2_60_0&TRANSPARENT=TRUE&theme=0&navtoken=eyJrZXkiOiJOYXZpb25pY3Nfd2ViYXBpXzAzNzkzIiwia2V5RG9tYWluIjoidXNhLmZpc2hlcm1hcC5vcmciLCJyZWZlcmVyIjoidXNhLmZpc2hlcm1hcC5vcmciLCJyYW5kb20iOjE2NzA3Mzc0ODQwMDd9'
    headers = {'referer': 'https://usa.fishermap.org/', 'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36'}
    response = requests.get(url,headers=headers)

    with open(img_filename, 'wb') as f:
        for chunk in response.iter_content():
            f.write(chunk)

    #read the image
    im = Image.open(img_filename)

    #show image
    im.show()

# %%
# Image.open('img.png')
_test_params(16,18696,25103)
# _test_params(16,18696,25102)
# _test_params(16,18696,25101)
# _test_params(16,18696,25100)
# _test_params(16,18695,25100)
# _test_params(16,18695,25101)
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17476/3074578363.py in <module>
#       1 # Image.open('img.png')
# ----> 2 _test_params(16,18696,25103)
#       3 # _test_params(16,18696,25102)
#       4 # _test_params(16,18696,25101)
#       5 # _test_params(16,18696,25100)
#
# ~\AppData\Local\Temp/ipykernel_17476/603747543.py in _test_params(p1, p2, p3, img_filename)
#       9
#      10     #read the image
# ---> 11     im = Image.open(img_filename)
#      12
#      13     #show image
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    3006     for message in accept_warnings:
#    3007         warnings.warn(message)
# -> 3008     raise UnidentifiedImageError(
#    3009         "cannot identify image file %r" % (filename if filename else fp)
#    3010     )
#
# UnidentifiedImageError: cannot identify image file 'img.jpg'

# %%
from bs4 import BeautifulSoup
import requests
import re
import json
import pandas as pd

url = 'https://fishing-app.gpsnauticalcharts.com/i-boating-fishing-web-app/fishing-marine-charts-navigation.html?title=Carvins+Cove+Reservoir+boating+app#16.16/37.38583/-79.94964'
r = requests.get(url, headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36'})

soup = BeautifulSoup(r.content)
s = str(soup)

with open('bath_html1.txt', 'w', encoding='UTF-8') as f:
    f.write(s)

# %%
import osmium

class CounterHandler(osmium.SimpleHandler):
    def __init__(self):
        osmium.SimpleHandler.__init__(self)
        self.num_nodes = 0

    def node(self, n):
        self.num_nodes += 1

# %%
# print("Number of nodes: %d" % h.num_nodes)

with open('2.pbf', mode='rb') as file: # b is important -> binary
    fileContent = file.read()
print(fileContent)
# Out:
xcf\x01\x10\n\x07\x0b\t\x00\x00\n\t\n\tD\x0c\n\x17\x13\t\x00\x00\n\x0f\x06\t\x00\x00\n\x05\x00\t\x00\x00\n\x03\x04\t\x11\x01\n\x01\x00\t\x00\x00\n\x15\x10\tx\x00\n\r\r\t\x00\x00\n\r\n\t.\x05\n\x05\x00\t\x00\x00\n\x0b\n\t\xc0\x01h\x12 /-\x17\t\x00\x00\n\t\x06\t\x16B\n\x02\x00\tSN\nRM\t]N\n\x0c\x00\t\t\x12\n\x01\x11\x12#\x08\xb6\x04\x12\x12\x00\x00\x01\x00\x02\x04\x07\x05\x08\x06\x03\x02\x04\x00\x05\x02\x06\x07\x18\x02"\x08\t\xdc>\xd2<\n\x1c+\x12;\x08\xba\x04\x12\x12\x00\x00\x01\x00\x02\x04\x07\x05\x08\x06\x03\x02\x04\x00\x05\x02\x06\x07\x18\x02" \t\xb8;\xc8;\n\n\x0f\t\x1d\x0e\n\n\x02\t\x1d&\n\x14\'\t\x10\x00\n\x04\x02\t\t\x00\n\x06\x01\x12M\x08\xbb\x04\x12\x12\x00\x00\x01\x00\x02\x04\x07\x05\x08\x06\x03\x02\x04\x00\x05\x02\x06\x07\x18\x02"2\t\xc49\xcc;\n\x06\x1f\t\r\x1a\n\x08\x06\t\x15\x02\n\x0e\x07\t\x0f\x08\n\x02\x00\t\x0f\x14\n\x0e\x13\t\x0f\x12\n\x02\x02\t\x0b\x00\n\n\x01\t\x0b\x02\n\x02\x00\x12k\x08\xbe\x04\x12\x12\x00\x00\x01\x00\x02\x04\x07\x05\x08\x06\x03\x02\x04\x00\x05\x02\x06\x07\x18\x02"P\t\xf05\xa6;\n\x0e\r\t\x11\x0e\n\x04\x00\t\x05\x0c\n\x02\x0b\t$J\n#=\t\x00\x00\n\x01\x00\t*L\n\n\x17\t\x00\x00\n\r\n\t\x02\x0c\n\x02\x02\t\x07\x14\n\x06\x15\t\x06\x18\n\t\t\t\x00\x00\n\x01\x08\t\x18\x14\n\x07\x11\t\x00\x00\n\x03\x00\x12q\x08\xbf\x04\x12\x12\x00\x00\x01\x00\x02\x04\x07\x05\x08\x06\x03\x02\x04\x00\x05\x02\x06\x07\x18\x02"V\t\xbc>\xea<\n \x17\t!\x16\n\x02\x02\t\x1b\x16\n\x1a\x17\t\x1b\x18\n\x02\x00\t!\x9e\x01\x1a\x14#\x13\' Q\tm\x88\x01\n\x04\x02\t\x05\x01\n\x02\x00\t\x06\x02\n\x16\n\t\x17\t\n\x02\x00\t\x1c\x08\n\x14\x0c\t\x19\t\n\x06\x01\t\x1e\n\n\x0e\x02\t\x17\x00\n\n\x01\x12m\x08\xc0\x04\x12\x12\x00\x00\x01\x00\x02\x04\x07\x05\x08\x06\x03\x02\x04\x00\x05\x02\x06\x07\x18\x02"R\t\xd6<\x92=\n\x0b\x03\t*\x0e\n\x11\x0b\t\x00\x00\n\x0b\x02\t8\x16\n\r\r\t\x00\x00\n\x0b\x02\t:(\n\x15\x1b\t\x00\x00\n\t\x00\t:>\x12\x04\x11\x19\x0f\t\x00\x00\n\x03\x00\t\x08 \n\x06\x02\t\r"\n\x08#\t\x0c\x00\n\x06\x02\t\x0b\x00\n\x06\x01\x12k\x08\xc1\x04\x12\x12\x00\x00\x01\x00\x02\x04\x07\x05\x08\x06\x03\x02\x04\x00\x05\x02\x06\x07\x18\x02"P\t\xfc;\xea<\n\x00\x06\t\x04\x00\n\x00\n\t\x03\t\n\x04\x00\t\x0c\x00\n\x18\x1c\t\x1d\x13\n\x06\x07\t\x07\x08\n\x02\x00\t\x05\ ...
