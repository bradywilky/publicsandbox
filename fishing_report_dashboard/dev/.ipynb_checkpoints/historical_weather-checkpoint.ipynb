# %%
# Import Meteostat library and dependencies
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Daily, Hourly

# %% [markdown]
# ### meteostat Parameter documentation:
# ### https://dev.meteostat.net/formats.html#meteorological-parameters

# %%
# Set time period
start = datetime(2023, 1, 1)
end = datetime(2023, 3, 1)



# Create Point for Vancouver, BC
# location = Point(49.2497, -123.1193, 70)

# Roanoke home launch
# 37.25511924499429, -79.94058843602322
location = Point(37.25511924499429, -79.94058843602322)

# Get daily data
data = Daily(location, start, end)
data = data.fetch()

# Plot line chart including average, minimum and maximum temperature
data.plot(y=['tavg', 'tmin', 'tmax'])
plt.show()

# %%
# Get hourly data
data = Hourly(location, start, end)
data = data.fetch()

data
# Out:
# ...
#                      temp  dwpt  rhum  prcp  snow   wdir  wspd  wpgt    pres  \
# time
# 2023-01-01 00:00:00   9.0   7.9  93.0   0.0   NaN  154.0   3.7   NaN  1014.0
# 2023-01-01 01:00:00   8.0   7.6  97.0   0.0   NaN  245.0   5.5   NaN  1015.0
# 2023-01-01 02:00:00  11.1  10.0  93.0   0.0   NaN  260.0   9.4   NaN  1014.3
# 2023-01-01 03:00:00  10.0   8.3  89.0   0.0   NaN  230.0   7.0   NaN  1015.0
# 2023-01-01 04:00:00  10.0   8.3  89.0   0.0   NaN  200.0   7.0   NaN  1015.0
# ...                   ...   ...   ...   ...   ...    ...   ...   ...     ...
# 2023-02-28 20:00:00  22.0  -2.0  20.0   0.0   NaN  300.0  15.0   NaN  1010.0
# 2023-02-28 21:00:00  21.1  -2.1  21.0   0.0   NaN  330.0  22.3   NaN  1009.6
# 2023-02-28 22:00:00  18.9  -3.3  22.0   0.0   NaN  350.0  18.4   NaN  1010.8
# 2023-02-28 23:00:00  17.2  -2.0  27.0   0.0   NaN   30.0  11.2   NaN  1012.0
# 2023-03-01 00:00:00  17.0  -2.1  27.0   0.0   NaN   30.0   7.0   NaN  1013.0
#
#                      tsun  coco
# ...

# %%
# Plot line chart including average, minimum and maximum temperature
data.plot(y='temp')
plt.show()

# %%
import requests
from bs4 import BeautifulSoup


r = requests.get('https://dev.meteostat.net/formats.html#meteorological-parameters')
soup = BeautifulSoup(r.text)

# %%
soup.findAll('table')[0]
# Out:
# <table><thead><tr><th style="text-align:left;"><strong>Code</strong></th> <th style="text-align:left;"><strong>Meaning</strong></th></tr></thead> <tbody><tr><td style="text-align:left;">TEMP</td> <td style="text-align:left;">Air Temperature</td></tr> <tr><td style="text-align:left;">TAVG</td> <td style="text-align:left;">Average Temperature</td></tr> <tr><td style="text-align:left;">TMIN</td> <td style="text-align:left;">Minimum Temperature</td></tr> <tr><td style="text-align:left;">TMAX</td> <td style="text-align:left;">Maximum Temperature</td></tr> <tr><td style="text-align:left;">DWPT</td> <td style="text-align:left;">Dew Point</td></tr> <tr><td style="text-align:left;">PRCP</td> <td style="text-align:left;">Total Precipitation</td></tr> <tr><td style="text-align:left;">WDIR</td> <td style="text-align:left;">Wind (From) Direction</td></tr> <tr><td style="text-align:left;">WSPD</td> <td style="text-align:left;">Average Wind Speed</td></tr> <tr><td style="text-align:left;">WPGT</td>
# ...

# %%
import pandas as pd

meteo_meta_url = 'https://dev.meteostat.net/formats.html#meteorological-parameters'
col_meaning = pd.read_html(meteo_meta_url,
             match = 'Meaning'
            )
# Out:
# [    Code                  Meaning
#  0   TEMP          Air Temperature
#  1   TAVG      Average Temperature
#  2   TMIN      Minimum Temperature
#  3   TMAX      Maximum Temperature
#  4   DWPT                Dew Point
#  5   PRCP      Total Precipitation
#  6   WDIR    Wind (From) Direction
#  7   WSPD       Average Wind Speed
#  8   WPGT           Wind Peak Gust
#  9   RHUM        Relative Humidity
#  10  PRES   Sea-Level Air Pressure
#  11  SNOW               Snow Depth
#  12  TSUN  Total Sunshine Duration
#  13  COCO   Weather Condition Code]
