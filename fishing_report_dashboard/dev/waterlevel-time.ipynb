# %%
# changing directory so I can import
import os
os.chdir('C:\\Users\\15714\\Documents\\repositories\\publicsandbox\\fishing_report_dashboard')


from water_data import get_usgs_water_data

# %%
'''
site
    02055080: ROANOKE RIVER AT THIRTEENTH ST BR AT ROANOKE, VA
    02054750: ROANOKE RIVER AT ROUTE 117 AT ROANOKE, VA
    02056000: ROANOKE RIVER AT NIAGARA, VA
    02055000: ROANOKE RIVER AT ROANOKE, VA
    
    01647600: POTOMAC RIVER AT WISCONSIN AVE, WASHINGTON, DC

param_cd
    00010: water temperature
    00065: height (feet)
'''

# %%
site = '01647600'
param_cd = '00065'
start_dt = '2023-02-20T19:17:43.422-05:00'
end_dt = '2023-02-26T19:17:43.422-05:00'

df = get_usgs_water_data(site, param_cd, start_dt, end_dt)

df
# Out:
#      agency_cd  site_no          datetime tz_cd  69944_00065 69944_00065_cd  \
# 0         USGS  1647600  2023-02-20 19:18   EST         2.42              P
# 1         USGS  1647600  2023-02-20 19:24   EST         2.46              P
# 2         USGS  1647600  2023-02-20 19:30   EST         2.46              P
# 3         USGS  1647600  2023-02-20 19:36   EST         2.50              P
# 4         USGS  1647600  2023-02-20 19:42   EST         2.51              P
# ...        ...      ...               ...   ...          ...            ...
# 1435      USGS  1647600  2023-02-26 18:48   EST        -0.07              P
# 1436      USGS  1647600  2023-02-26 18:54   EST        -0.06              P
# 1437      USGS  1647600  2023-02-26 19:00   EST        -0.10              P
# 1438      USGS  1647600  2023-02-26 19:06   EST        -0.14              P
# 1439      USGS  1647600  2023-02-26 19:12   EST        -0.15              P
#
#       69945_00065 69945_00065_cd
# ...
