# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xgboost as xgb
pd.set_option('display.float_format', '{:.0f}'.format)

# %%
def get_dataframe():
    label = pd.read_csv('water_temp_dc_2016_2024_hourly.csv')[['t', 'v']]
    weather = pd.read_csv('cln_dc_weather_2016_2024_hourly.csv')    
    label['t'] = pd.to_datetime(label['t'])
    label['dt_est'] = label['t'].astype('int64') // 1e9
    df = pd.merge(label, weather, on='dt_est', how='inner')
    df.index = df['t']
    
    return df


def preprocess(df, features=None):
    df = df[df['v'].notna()]
    if features:
        for f in features:
            df = df[df[f].notna()]
    
    return df


def split_train_test(df):
    train_df = df.loc[df.index < '2023-01-01 00:00:00']
    test_df = df.loc[df.index >= '2023-01-01 00:00:00']

    return train_df, test_df


def split_features_target(train_df, test_df, FEATURES, TARGET):
    X_train = train_df[FEATURES]
    y_train = train_df[TARGET]
    
    X_test = test_df[FEATURES]
    y_test = test_df[TARGET]

    return X_train, y_train, X_test, y_test

# %%
'''
This is for simulating a live predictive forecaster that uses the prior hour's temperature as a feature. In live use, if we want to
predict the next 7 days of water temperature, the model won't know the prior hour's temperature at any given point in the future, since
it hasn't happened yet. So we need to make stepwise predictions and set the next point's "v_minus_1hr" as the current point's prediction
value.

*Requires a model that uses "v_minus_1hr" as a feature
'''
def predict_stepwise(X_test, model):
    # Initialize an empty list to store predictions
    stepwise_preds = []
    
    # Iterate through X_test by its index, except the last row for which there is no "next point"
    for position in range(len(X_test) - 1):
        # Select current point
        current_point = X_test.iloc[[position]]
        
        # Predict on current_point and store the prediction
        current_pred = model.predict(current_point)
        stepwise_preds.append(current_pred.item())  # Assuming model.predict returns an array, use .item() to get the value
        
        # Update 'v_minus_1hr' for the next point
        next_position = position + 1
        X_test.iloc[next_position, X_test.columns.get_loc('v_minus_1hr')] = current_pred
    
    # Handle prediction for the last row separately if needed
    last_point = X_test.iloc[[-1]]
    last_pred = model.predict(last_point)
    stepwise_preds.append(last_pred.item())
    
    return stepwise_preds

# %%
df = get_dataframe()
df = preprocess(df)

df['month'] = df.index.month
df['hour'] = df.index.hour
df['day'] = df.index.day

train_df, test_df = split_train_test(df)

FEATURES = ['month', 'hour', 'day']
TARGET = 'v'

X_train, y_train, X_test, y_test = split_features_target(train_df, test_df, FEATURES, TARGET)

model = xgb.XGBRegressor()
model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_test, y_test)])
# Out:
# [0]	validation_0-rmse:11.67742	validation_1-rmse:10.57751
# [1]	validation_0-rmse:8.48326	validation_1-rmse:7.37743
# [2]	validation_0-rmse:6.35183	validation_1-rmse:5.27830
# [3]	validation_0-rmse:4.98283	validation_1-rmse:3.97357
# [4]	validation_0-rmse:4.14600	validation_1-rmse:3.28186
# [5]	validation_0-rmse:3.64815	validation_1-rmse:2.94246
# [6]	validation_0-rmse:3.38218	validation_1-rmse:2.83263
# [7]	validation_0-rmse:3.23333	validation_1-rmse:2.81660
# [8]	validation_0-rmse:3.15408	validation_1-rmse:2.83828
# [9]	validation_0-rmse:3.11329	validation_1-rmse:2.86271
# [10]	validation_0-rmse:3.08834	validation_1-rmse:2.89695
# [11]	validation_0-rmse:3.07209	validation_1-rmse:2.90406
# [12]	validation_0-rmse:3.06501	validation_1-rmse:2.92200
# [13]	validation_0-rmse:3.06003	validation_1-rmse:2.93137
# [14]	validation_0-rmse:3.05725	validation_1-rmse:2.94000
# [15]	validation_0-rmse:3.05583	validation_1-rmse:2.94629
# [16]	validation_0-rmse:3.05308	validation_1-rmse:2.95003
# [17]	validation_0-rmse:3.05231	validation_1-rmse:2.95273
# [18]	validation_0-rmse:3.05184	validation_1-rmse:2.95497
# [19]	validation_0-rmse:3.04962	validation_1-rmse:2.95789
# [20]	validation_0-rmse:3.04886	validation_1-rmse:2.96055
# [21]	validation_0-rmse:3.04865	validation_1-rmse:2.96110
# [22]	validation_0-rmse:3.04704	validation_1-rmse:2.96523
# [23]	validation_0-rmse:3.04686	validation_1-rmse:2.96623
# [24]	validation_0-rmse:3.04651	validation_1-rmse:2.96829
# [25]	validation_0-rmse:3.04584	validation_1-rmse:2.96985
# [26]	validation_0-rmse:3.04560	validation_1-rmse:2.97020
# [27]	validation_0-rmse:3.04544	validation_1-rmse:2.97098
# [28]	validation_0-rmse:3.04533	validation_1-rmse:2.97138
# [29]	validation_0-rmse:3.04523	validation_1-rmse:2.97171
# [30]	validation_0-rmse:3.04511	validation_1-rmse:2.97224
# [31]	validation_0-rmse:3.04499	validation_1-rmse:2.97249
# [32]	validation_0-rmse:3.04485	validation_1-rmse:2.97208
# [33]	validation_0-rmse:3.04459	validation_1-rmse:2.97460
# [34]	validation_0-rmse:3.04441	validation_1-rmse:2.97624
# [35]	validation_0-rmse:3.04418	validation_1-rmse:2.97783
# [36]	validation_0-rmse:3.04414	validation_1-rmse:2.97764
# [37]	validation_0-rmse:3.04403	validation_1-rmse:2.97789
# [38]	validation_0-rmse:3.04389	validation_1-rmse:2.97785
# [39]	validation_0-rmse:3.04382	validation_1-rmse:2.97790
# [40]	validation_0-rmse:3.04374	validation_1-rmse:2.97847
# [41]	validation_0-rmse:3.04365	validation_1-rmse:2.97814
# [42]	validation_0-rmse:3.04360	validation_1-rmse:2.97807
# [43]	validation_0-rmse:3.04357	validation_1-rmse:2.97812
# [44]	validation_0-rmse:3.04349	validation_1-rmse:2.97878
# [45]	validation_0-rmse:3.04333	validation_1-rmse:2.97978
# [46]	validation_0-rmse:3.04328	validation_1-rmse:2.97979
# [47]	validation_0-rmse:3.04325	validation_1-rmse:2.97986
# [48]	validation_0-rmse:3.04320	validation_1-rmse:2.97973
# [49]	validation_0-rmse:3.04307	validation_1-rmse:2.97956
# [50]	validation_0-rmse:3.04295	validation_1-rmse:2.97988
# [51]	validation_0-rmse:3.04292	validation_1-rmse:2.98016
# [52]	validation_0-rmse:3.04289	validation_1-rmse:2.98040
# [53]	validation_0-rmse:3.04282	validation_1-rmse:2.98049
# [54]	validation_0-rmse:3.04274	validation_1-rmse:2.98055
# [55]	validation_0-rmse:3.04268	validation_1-rmse:2.98099
# [56]	validation_0-rmse:3.04264	validation_1-rmse:2.98059
# [57]	validation_0-rmse:3.04257	validation_1-rmse:2.98112
# [58]	validation_0-rmse:3.04253	validation_1-rmse:2.98117
# [59]	validation_0-rmse:3.04250	validation_1-rmse:2.98092
# [60]	validation_0-rmse:3.04248	validation_1-rmse:2.98077
# [61]	validation_0-rmse:3.04246	validation_1-rmse:2.98080
# [62]	validation_0-rmse:3.04242	validation_1-rmse:2.98074
# [63]	validation_0-rmse:3.04239	validation_1-rmse:2.98069
# [64]	validation_0-rmse:3.04236	validation_1-rmse:2.98104
# [65]	validation_0-rmse:3.04234	validation_1-rmse:2.98117
# [66]	validation_0-rmse:3.04231	validation_1-rmse:2.98123
# [67]	validation_0-rmse:3.04229	validation_1-rmse:2.98136
# [68]	validation_0-rmse:3.04224	validation_1-rmse:2.98158
# [69]	validation_0-rmse:3.04222	validation_1-rmse:2.98163
# [70]	validation_0-rmse:3.04217	validation_1-rmse:2.98192
# [71]	validation_0-rmse:3.04215	validation_1-rmse:2.98207
# [72]	validation_0-rmse:3.04212	validation_1-rmse:2.98183
# [73]	validation_0-rmse:3.04210	validation_1-rmse:2.98189
# [74]	validation_0-rmse:3.04207	validation_1-rmse:2.98193
# [75]	validation_0-rmse:3.04203	validation_1-rmse:2.98203
# [76]	validation_0-rmse:3.04201	validation_1-rmse:2.98239
# [77]	validation_0-rmse:3.04199	validation_1-rmse:2.98251
# [78]	validation_0-rmse:3.04196	validation_1-rmse:2.98253
# [79]	validation_0-rmse:3.04194	validation_1-rmse:2.98258
# [80]	validation_0-rmse:3.04193	validation_1-rmse:2.98279
# [81]	validation_0-rmse:3.04192	validation_1-rmse:2.98284
# [82]	validation_0-rmse:3.04189	validation_1-rmse:2.98271
# [83]	validation_0-rmse:3.04186	validation_1-rmse:2.98264
# [84]	validation_0-rmse:3.04184	validation_1-rmse:2.98270
# [85]	validation_0-rmse:3.04181	validation_1-rmse:2.98280
# [86]	validation_0-rmse:3.04178	validation_1-rmse:2.98288
# [87]	validation_0-rmse:3.04176	validation_1-rmse:2.98281
# [88]	validation_0-rmse:3.04173	validation_1-rmse:2.98278
# [89]	validation_0-rmse:3.04171	validation_1-rmse:2.98287
# [90]	validation_0-rmse:3.04170	validation_1-rmse:2.98276
# [91]	validation_0-rmse:3.04168	validation_1-rmse:2.98278
# [92]	validation_0-rmse:3.04166	validation_1-rmse:2.98283
# [93]	validation_0-rmse:3.04165	validation_1-rmse:2.98293
# [94]	validation_0-rmse:3.04162	validation_1-rmse:2.98306
# [95]	validation_0-rmse:3.04161	validation_1-rmse:2.98299
# [96]	validation_0-rmse:3.04159	validation_1-rmse:2.98304
# [97]	validation_0-rmse:3.04158	validation_1-rmse:2.98312
# [98]	validation_0-rmse:3.04156	validation_1-rmse:2.98328
# [99]	validation_0-rmse:3.04154	validation_1-rmse:2.98330
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_pred = model.predict(X_test)

plt.scatter(test_df.index, y_pred, label='Validation Data', color='blue', s=1)

# Scatter plot for testing data in another color, e.g., red
plt.scatter(test_df.index, test_df['v'], label='Test Data', color='red', s=1) # s is the size of the marker

# Adding labels and title for clarity
plt.xlabel('Time')
plt.ylabel('v')
plt.title('Validation vs Test Data Scatter Plot')
plt.legend()

# Show plot
plt.show()

# %%
df = get_dataframe()
df = preprocess(df, features=FEATURES)

df['month'] = df.index.month
df['hour'] = df.index.hour
df['day'] = df.index.day

train_df, test_df = split_train_test(df)

FEATURES = ['month', 'hour', 'day', 'temp']
TARGET = 'v'

X_train, y_train, X_test, y_test = split_features_target(train_df, test_df, FEATURES, TARGET)

model = xgb.XGBRegressor()
model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_test, y_test)])
# Out:
# [0]	validation_0-rmse:11.69338	validation_1-rmse:10.68061
# [1]	validation_0-rmse:8.50535	validation_1-rmse:7.57526
# [2]	validation_0-rmse:6.38736	validation_1-rmse:5.51370
# [3]	validation_0-rmse:5.01482	validation_1-rmse:4.24778
# [4]	validation_0-rmse:4.14673	validation_1-rmse:3.52438
# [5]	validation_0-rmse:3.61663	validation_1-rmse:3.14607
# [6]	validation_0-rmse:3.31163	validation_1-rmse:2.98547
# [7]	validation_0-rmse:3.13597	validation_1-rmse:2.93107
# [8]	validation_0-rmse:3.02518	validation_1-rmse:2.92107
# [9]	validation_0-rmse:2.96045	validation_1-rmse:2.93643
# [10]	validation_0-rmse:2.89562	validation_1-rmse:2.92412
# [11]	validation_0-rmse:2.85832	validation_1-rmse:2.92465
# [12]	validation_0-rmse:2.82746	validation_1-rmse:2.90093
# [13]	validation_0-rmse:2.80057	validation_1-rmse:2.90070
# [14]	validation_0-rmse:2.78366	validation_1-rmse:2.90414
# [15]	validation_0-rmse:2.77663	validation_1-rmse:2.90441
# [16]	validation_0-rmse:2.76629	validation_1-rmse:2.89948
# [17]	validation_0-rmse:2.75050	validation_1-rmse:2.90478
# [18]	validation_0-rmse:2.74707	validation_1-rmse:2.90647
# [19]	validation_0-rmse:2.73754	validation_1-rmse:2.91222
# [20]	validation_0-rmse:2.73481	validation_1-rmse:2.91335
# [21]	validation_0-rmse:2.73215	validation_1-rmse:2.91427
# [22]	validation_0-rmse:2.73053	validation_1-rmse:2.91615
# [23]	validation_0-rmse:2.71879	validation_1-rmse:2.90992
# [24]	validation_0-rmse:2.71237	validation_1-rmse:2.90795
# [25]	validation_0-rmse:2.70829	validation_1-rmse:2.90798
# [26]	validation_0-rmse:2.70481	validation_1-rmse:2.90848
# [27]	validation_0-rmse:2.69779	validation_1-rmse:2.91232
# [28]	validation_0-rmse:2.69047	validation_1-rmse:2.91362
# [29]	validation_0-rmse:2.68553	validation_1-rmse:2.91067
# [30]	validation_0-rmse:2.68283	validation_1-rmse:2.90954
# [31]	validation_0-rmse:2.67721	validation_1-rmse:2.91022
# [32]	validation_0-rmse:2.67547	validation_1-rmse:2.90995
# [33]	validation_0-rmse:2.67200	validation_1-rmse:2.91113
# [34]	validation_0-rmse:2.66957	validation_1-rmse:2.90777
# [35]	validation_0-rmse:2.66542	validation_1-rmse:2.90597
# [36]	validation_0-rmse:2.66325	validation_1-rmse:2.90683
# [37]	validation_0-rmse:2.65877	validation_1-rmse:2.91385
# [38]	validation_0-rmse:2.65508	validation_1-rmse:2.91684
# [39]	validation_0-rmse:2.65170	validation_1-rmse:2.91772
# [40]	validation_0-rmse:2.64804	validation_1-rmse:2.91712
# [41]	validation_0-rmse:2.64555	validation_1-rmse:2.91816
# [42]	validation_0-rmse:2.64351	validation_1-rmse:2.91755
# [43]	validation_0-rmse:2.63896	validation_1-rmse:2.92152
# [44]	validation_0-rmse:2.63448	validation_1-rmse:2.92900
# [45]	validation_0-rmse:2.63266	validation_1-rmse:2.92876
# [46]	validation_0-rmse:2.63003	validation_1-rmse:2.92957
# [47]	validation_0-rmse:2.62679	validation_1-rmse:2.93024
# [48]	validation_0-rmse:2.62506	validation_1-rmse:2.92956
# [49]	validation_0-rmse:2.61978	validation_1-rmse:2.93217
# [50]	validation_0-rmse:2.61627	validation_1-rmse:2.93860
# [51]	validation_0-rmse:2.61318	validation_1-rmse:2.93976
# [52]	validation_0-rmse:2.61152	validation_1-rmse:2.94022
# [53]	validation_0-rmse:2.60925	validation_1-rmse:2.94013
# [54]	validation_0-rmse:2.60688	validation_1-rmse:2.94169
# [55]	validation_0-rmse:2.60275	validation_1-rmse:2.94406
# [56]	validation_0-rmse:2.60180	validation_1-rmse:2.94466
# [57]	validation_0-rmse:2.59924	validation_1-rmse:2.94960
# [58]	validation_0-rmse:2.59552	validation_1-rmse:2.94974
# [59]	validation_0-rmse:2.59192	validation_1-rmse:2.95294
# [60]	validation_0-rmse:2.58870	validation_1-rmse:2.95451
# [61]	validation_0-rmse:2.58692	validation_1-rmse:2.95387
# [62]	validation_0-rmse:2.58470	validation_1-rmse:2.95533
# [63]	validation_0-rmse:2.58208	validation_1-rmse:2.96001
# [64]	validation_0-rmse:2.57824	validation_1-rmse:2.95993
# [65]	validation_0-rmse:2.57689	validation_1-rmse:2.96066
# [66]	validation_0-rmse:2.57301	validation_1-rmse:2.96069
# [67]	validation_0-rmse:2.56977	validation_1-rmse:2.95902
# [68]	validation_0-rmse:2.56795	validation_1-rmse:2.95888
# [69]	validation_0-rmse:2.56626	validation_1-rmse:2.95795
# [70]	validation_0-rmse:2.56323	validation_1-rmse:2.95992
# [71]	validation_0-rmse:2.56054	validation_1-rmse:2.96185
# [72]	validation_0-rmse:2.55843	validation_1-rmse:2.96432
# [73]	validation_0-rmse:2.55618	validation_1-rmse:2.96701
# [74]	validation_0-rmse:2.55402	validation_1-rmse:2.96735
# [75]	validation_0-rmse:2.55343	validation_1-rmse:2.96827
# [76]	validation_0-rmse:2.55073	validation_1-rmse:2.97023
# [77]	validation_0-rmse:2.54872	validation_1-rmse:2.96752
# [78]	validation_0-rmse:2.54724	validation_1-rmse:2.96741
# [79]	validation_0-rmse:2.54594	validation_1-rmse:2.96761
# [80]	validation_0-rmse:2.54370	validation_1-rmse:2.96946
# [81]	validation_0-rmse:2.54174	validation_1-rmse:2.97026
# [82]	validation_0-rmse:2.53779	validation_1-rmse:2.97279
# [83]	validation_0-rmse:2.53500	validation_1-rmse:2.97293
# [84]	validation_0-rmse:2.53360	validation_1-rmse:2.97478
# [85]	validation_0-rmse:2.53287	validation_1-rmse:2.97480
# [86]	validation_0-rmse:2.53047	validation_1-rmse:2.97581
# [87]	validation_0-rmse:2.52841	validation_1-rmse:2.97635
# [88]	validation_0-rmse:2.52623	validation_1-rmse:2.97695
# [89]	validation_0-rmse:2.52542	validation_1-rmse:2.97733
# [90]	validation_0-rmse:2.52437	validation_1-rmse:2.97764
# [91]	validation_0-rmse:2.52098	validation_1-rmse:2.97867
# [92]	validation_0-rmse:2.51686	validation_1-rmse:2.98218
# [93]	validation_0-rmse:2.51457	validation_1-rmse:2.98273
# [94]	validation_0-rmse:2.51300	validation_1-rmse:2.98210
# [95]	validation_0-rmse:2.51106	validation_1-rmse:2.98248
# [96]	validation_0-rmse:2.50872	validation_1-rmse:2.98240
# [97]	validation_0-rmse:2.50781	validation_1-rmse:2.98266
# [98]	validation_0-rmse:2.50748	validation_1-rmse:2.98334
# [99]	validation_0-rmse:2.50539	validation_1-rmse:2.98639
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_pred = model.predict(X_test)

plt.scatter(test_df.index, y_pred, label='Validation Data', color='blue', s=1)

# Scatter plot for testing data in another color, e.g., red
plt.scatter(test_df.index, test_df['v'], label='Test Data', color='red', s=1) # s is the size of the marker

# Adding labels and title for clarity
plt.xlabel('Time')
plt.ylabel('v')
plt.title('Validation vs Test Data Scatter Plot')
plt.legend()

# Show plot
plt.show()

# %%
df = get_dataframe()
one_hour_in_seconds = 3600
for i in range(1,3):
    df[f'dt_est_minus_{i}hr'] = df['dt_est'] - i*one_hour_in_seconds

    watertemp = df[['dt_est', 'v']]
    watertemp.columns = [f'{c}_minus_{i}hr' for c in watertemp.columns]

    airtemp = df[['dt_est', 'temp']]
    airtemp.columns = [f'{c}_minus_{i}hr' for c in airtemp.columns]
    
    df = pd.merge(df, airtemp, on=f'dt_est_minus_{i}hr', how='inner')
    df = pd.merge(df, watertemp, on=f'dt_est_minus_{i}hr', how='inner')

FEATURES = ['month', 'hour', 'day', 'temp_minus_2hr', 'temp_minus_1hr', 'temp', 'humidity', 'clouds_all', 'v_minus_1hr']
TARGET = 'v'

df.index = df['t']
df['month'] = df.index.month
df['hour'] = df.index.hour
df['day'] = df.index.day

df = preprocess(df, features=FEATURES)
train_df, test_df = split_train_test(df)
X_train, y_train, X_test, y_test = split_features_target(train_df, test_df, FEATURES, TARGET)

model = xgb.XGBRegressor()
model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_test, y_test)])
# Out:
# [0]	validation_0-rmse:11.46629	validation_1-rmse:10.69248
# [1]	validation_0-rmse:8.03146	validation_1-rmse:7.48975
# [2]	validation_0-rmse:5.62648	validation_1-rmse:5.24593
# [3]	validation_0-rmse:3.94287	validation_1-rmse:3.67764
# [4]	validation_0-rmse:2.76477	validation_1-rmse:2.57846
# [5]	validation_0-rmse:1.94112	validation_1-rmse:1.80849
# [6]	validation_0-rmse:1.36631	validation_1-rmse:1.27279
# [7]	validation_0-rmse:0.96638	validation_1-rmse:0.89999
# [8]	validation_0-rmse:0.68987	validation_1-rmse:0.64268
# [9]	validation_0-rmse:0.50099	validation_1-rmse:0.46716
# [10]	validation_0-rmse:0.37465	validation_1-rmse:0.34946
# [11]	validation_0-rmse:0.29299	validation_1-rmse:0.27273
# [12]	validation_0-rmse:0.24275	validation_1-rmse:0.22584
# [13]	validation_0-rmse:0.21315	validation_1-rmse:0.19820
# [14]	validation_0-rmse:0.19674	validation_1-rmse:0.18298
# [15]	validation_0-rmse:0.18781	validation_1-rmse:0.17459
# [16]	validation_0-rmse:0.18288	validation_1-rmse:0.16993
# [17]	validation_0-rmse:0.18022	validation_1-rmse:0.16777
# [18]	validation_0-rmse:0.17865	validation_1-rmse:0.16642
# [19]	validation_0-rmse:0.17770	validation_1-rmse:0.16569
# [20]	validation_0-rmse:0.17690	validation_1-rmse:0.16530
# [21]	validation_0-rmse:0.17616	validation_1-rmse:0.16491
# [22]	validation_0-rmse:0.17554	validation_1-rmse:0.16486
# [23]	validation_0-rmse:0.17488	validation_1-rmse:0.16505
# [24]	validation_0-rmse:0.17434	validation_1-rmse:0.16492
# [25]	validation_0-rmse:0.17408	validation_1-rmse:0.16491
# [26]	validation_0-rmse:0.17390	validation_1-rmse:0.16490
# [27]	validation_0-rmse:0.17368	validation_1-rmse:0.16500
# [28]	validation_0-rmse:0.17300	validation_1-rmse:0.16531
# [29]	validation_0-rmse:0.17244	validation_1-rmse:0.16520
# [30]	validation_0-rmse:0.17213	validation_1-rmse:0.16522
# [31]	validation_0-rmse:0.17183	validation_1-rmse:0.16525
# [32]	validation_0-rmse:0.17152	validation_1-rmse:0.16529
# [33]	validation_0-rmse:0.17120	validation_1-rmse:0.16537
# [34]	validation_0-rmse:0.17096	validation_1-rmse:0.16525
# [35]	validation_0-rmse:0.17056	validation_1-rmse:0.16548
# [36]	validation_0-rmse:0.17026	validation_1-rmse:0.16559
# [37]	validation_0-rmse:0.17006	validation_1-rmse:0.16546
# [38]	validation_0-rmse:0.16983	validation_1-rmse:0.16549
# [39]	validation_0-rmse:0.16938	validation_1-rmse:0.16555
# [40]	validation_0-rmse:0.16890	validation_1-rmse:0.16564
# [41]	validation_0-rmse:0.16838	validation_1-rmse:0.16556
# [42]	validation_0-rmse:0.16819	validation_1-rmse:0.16551
# [43]	validation_0-rmse:0.16800	validation_1-rmse:0.16546
# [44]	validation_0-rmse:0.16760	validation_1-rmse:0.16552
# [45]	validation_0-rmse:0.16757	validation_1-rmse:0.16551
# [46]	validation_0-rmse:0.16737	validation_1-rmse:0.16557
# [47]	validation_0-rmse:0.16728	validation_1-rmse:0.16558
# [48]	validation_0-rmse:0.16718	validation_1-rmse:0.16561
# [49]	validation_0-rmse:0.16702	validation_1-rmse:0.16559
# [50]	validation_0-rmse:0.16665	validation_1-rmse:0.16570
# [51]	validation_0-rmse:0.16619	validation_1-rmse:0.16571
# [52]	validation_0-rmse:0.16586	validation_1-rmse:0.16573
# [53]	validation_0-rmse:0.16571	validation_1-rmse:0.16577
# [54]	validation_0-rmse:0.16548	validation_1-rmse:0.16572
# [55]	validation_0-rmse:0.16534	validation_1-rmse:0.16567
# [56]	validation_0-rmse:0.16519	validation_1-rmse:0.16571
# [57]	validation_0-rmse:0.16497	validation_1-rmse:0.16590
# [58]	validation_0-rmse:0.16486	validation_1-rmse:0.16588
# [59]	validation_0-rmse:0.16454	validation_1-rmse:0.16597
# [60]	validation_0-rmse:0.16426	validation_1-rmse:0.16617
# [61]	validation_0-rmse:0.16410	validation_1-rmse:0.16621
# [62]	validation_0-rmse:0.16405	validation_1-rmse:0.16621
# [63]	validation_0-rmse:0.16385	validation_1-rmse:0.16649
# [64]	validation_0-rmse:0.16356	validation_1-rmse:0.16655
# [65]	validation_0-rmse:0.16324	validation_1-rmse:0.16666
# [66]	validation_0-rmse:0.16315	validation_1-rmse:0.16666
# [67]	validation_0-rmse:0.16280	validation_1-rmse:0.16673
# [68]	validation_0-rmse:0.16240	validation_1-rmse:0.16666
# [69]	validation_0-rmse:0.16229	validation_1-rmse:0.16661
# [70]	validation_0-rmse:0.16194	validation_1-rmse:0.16668
# [71]	validation_0-rmse:0.16168	validation_1-rmse:0.16672
# [72]	validation_0-rmse:0.16153	validation_1-rmse:0.16672
# [73]	validation_0-rmse:0.16151	validation_1-rmse:0.16675
# [74]	validation_0-rmse:0.16122	validation_1-rmse:0.16673
# [75]	validation_0-rmse:0.16106	validation_1-rmse:0.16673
# [76]	validation_0-rmse:0.16082	validation_1-rmse:0.16670
# [77]	validation_0-rmse:0.16060	validation_1-rmse:0.16670
# [78]	validation_0-rmse:0.16042	validation_1-rmse:0.16675
# [79]	validation_0-rmse:0.16007	validation_1-rmse:0.16701
# [80]	validation_0-rmse:0.15976	validation_1-rmse:0.16716
# [81]	validation_0-rmse:0.15950	validation_1-rmse:0.16713
# [82]	validation_0-rmse:0.15929	validation_1-rmse:0.16712
# [83]	validation_0-rmse:0.15902	validation_1-rmse:0.16725
# [84]	validation_0-rmse:0.15887	validation_1-rmse:0.16730
# [85]	validation_0-rmse:0.15856	validation_1-rmse:0.16731
# [86]	validation_0-rmse:0.15849	validation_1-rmse:0.16728
# [87]	validation_0-rmse:0.15826	validation_1-rmse:0.16731
# [88]	validation_0-rmse:0.15819	validation_1-rmse:0.16731
# [89]	validation_0-rmse:0.15798	validation_1-rmse:0.16731
# [90]	validation_0-rmse:0.15771	validation_1-rmse:0.16733
# [91]	validation_0-rmse:0.15755	validation_1-rmse:0.16742
# [92]	validation_0-rmse:0.15740	validation_1-rmse:0.16753
# [93]	validation_0-rmse:0.15721	validation_1-rmse:0.16755
# [94]	validation_0-rmse:0.15707	validation_1-rmse:0.16764
# [95]	validation_0-rmse:0.15672	validation_1-rmse:0.16765
# [96]	validation_0-rmse:0.15655	validation_1-rmse:0.16772
# [97]	validation_0-rmse:0.15652	validation_1-rmse:0.16772
# [98]	validation_0-rmse:0.15627	validation_1-rmse:0.16772
# [99]	validation_0-rmse:0.15608	validation_1-rmse:0.16782
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
stepwise_preds = predict_stepwise(X_test, model)

# %%
plt.scatter(test_df.index, stepwise_preds, label='Validation Data', color='blue', s=1)

# Scatter plot for testing data in another color, e.g., red
plt.scatter(test_df.index, test_df['v'], label='Test Data', color='red', s=1) # s is the size of the marker

# Adding labels and title for clarity
plt.xlabel('Time')
plt.ylabel('v')
plt.title('Validation vs Test Data Scatter Plot')
plt.legend()

# Show plot
plt.show()

# %%
df = get_dataframe()

FEATURES = ['month', 'hour', 'day', 'temp', 'humidity', 'clouds_all',]
TARGET = 'v'

df.index = df['t']
df['month'] = df.index.month
df['hour'] = df.index.hour
df['day'] = df.index.day

df = preprocess(df, features=FEATURES)
train_df, test_df = split_train_test(df)
X_train, y_train, X_test, y_test = split_features_target(train_df, test_df, FEATURES, TARGET)

model = xgb.XGBRegressor()
model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_test, y_test)])
# Out:
# [0]	validation_0-rmse:11.69317	validation_1-rmse:10.67995
# [1]	validation_0-rmse:8.50467	validation_1-rmse:7.58045
# [2]	validation_0-rmse:6.36908	validation_1-rmse:5.53563
# [3]	validation_0-rmse:4.98971	validation_1-rmse:4.24465
# [4]	validation_0-rmse:4.11254	validation_1-rmse:3.49989
# [5]	validation_0-rmse:3.59310	validation_1-rmse:3.15373
# [6]	validation_0-rmse:3.29198	validation_1-rmse:3.00207
# [7]	validation_0-rmse:3.11271	validation_1-rmse:2.95796
# [8]	validation_0-rmse:2.99127	validation_1-rmse:2.91579
# [9]	validation_0-rmse:2.92185	validation_1-rmse:2.91237
# [10]	validation_0-rmse:2.85513	validation_1-rmse:2.91123
# [11]	validation_0-rmse:2.79935	validation_1-rmse:2.89719
# [12]	validation_0-rmse:2.76712	validation_1-rmse:2.89981
# [13]	validation_0-rmse:2.74614	validation_1-rmse:2.90508
# [14]	validation_0-rmse:2.72185	validation_1-rmse:2.90932
# [15]	validation_0-rmse:2.71163	validation_1-rmse:2.91222
# [16]	validation_0-rmse:2.70216	validation_1-rmse:2.91778
# [17]	validation_0-rmse:2.69412	validation_1-rmse:2.92243
# [18]	validation_0-rmse:2.68573	validation_1-rmse:2.92725
# [19]	validation_0-rmse:2.67655	validation_1-rmse:2.92649
# [20]	validation_0-rmse:2.67229	validation_1-rmse:2.92593
# [21]	validation_0-rmse:2.66063	validation_1-rmse:2.93401
# [22]	validation_0-rmse:2.65716	validation_1-rmse:2.93851
# [23]	validation_0-rmse:2.64755	validation_1-rmse:2.93832
# [24]	validation_0-rmse:2.63478	validation_1-rmse:2.94047
# [25]	validation_0-rmse:2.62770	validation_1-rmse:2.94493
# [26]	validation_0-rmse:2.62297	validation_1-rmse:2.94576
# [27]	validation_0-rmse:2.61879	validation_1-rmse:2.94716
# [28]	validation_0-rmse:2.61337	validation_1-rmse:2.94360
# [29]	validation_0-rmse:2.60934	validation_1-rmse:2.94337
# [30]	validation_0-rmse:2.59895	validation_1-rmse:2.94102
# [31]	validation_0-rmse:2.59414	validation_1-rmse:2.94380
# [32]	validation_0-rmse:2.59144	validation_1-rmse:2.94589
# [33]	validation_0-rmse:2.58220	validation_1-rmse:2.94647
# [34]	validation_0-rmse:2.57816	validation_1-rmse:2.94651
# [35]	validation_0-rmse:2.56871	validation_1-rmse:2.95277
# [36]	validation_0-rmse:2.55853	validation_1-rmse:2.94950
# [37]	validation_0-rmse:2.55328	validation_1-rmse:2.94968
# [38]	validation_0-rmse:2.54617	validation_1-rmse:2.95307
# [39]	validation_0-rmse:2.54135	validation_1-rmse:2.95661
# [40]	validation_0-rmse:2.53679	validation_1-rmse:2.95669
# [41]	validation_0-rmse:2.52782	validation_1-rmse:2.95831
# [42]	validation_0-rmse:2.52330	validation_1-rmse:2.95878
# [43]	validation_0-rmse:2.51932	validation_1-rmse:2.95956
# [44]	validation_0-rmse:2.51253	validation_1-rmse:2.96977
# [45]	validation_0-rmse:2.50501	validation_1-rmse:2.97366
# [46]	validation_0-rmse:2.49772	validation_1-rmse:2.97619
# [47]	validation_0-rmse:2.49440	validation_1-rmse:2.97392
# [48]	validation_0-rmse:2.49082	validation_1-rmse:2.97668
# [49]	validation_0-rmse:2.48613	validation_1-rmse:2.97655
# [50]	validation_0-rmse:2.48219	validation_1-rmse:2.97849
# [51]	validation_0-rmse:2.47862	validation_1-rmse:2.97976
# [52]	validation_0-rmse:2.47599	validation_1-rmse:2.97939
# [53]	validation_0-rmse:2.47117	validation_1-rmse:2.97714
# [54]	validation_0-rmse:2.46745	validation_1-rmse:2.97765
# [55]	validation_0-rmse:2.46264	validation_1-rmse:2.97769
# [56]	validation_0-rmse:2.45808	validation_1-rmse:2.97846
# [57]	validation_0-rmse:2.45628	validation_1-rmse:2.97790
# [58]	validation_0-rmse:2.45191	validation_1-rmse:2.97797
# [59]	validation_0-rmse:2.44856	validation_1-rmse:2.97729
# [60]	validation_0-rmse:2.44637	validation_1-rmse:2.97757
# [61]	validation_0-rmse:2.44249	validation_1-rmse:2.97670
# [62]	validation_0-rmse:2.43941	validation_1-rmse:2.97896
# [63]	validation_0-rmse:2.43507	validation_1-rmse:2.97877
# [64]	validation_0-rmse:2.42925	validation_1-rmse:2.98041
# [65]	validation_0-rmse:2.42569	validation_1-rmse:2.98025
# [66]	validation_0-rmse:2.42129	validation_1-rmse:2.97746
# [67]	validation_0-rmse:2.41893	validation_1-rmse:2.97755
# [68]	validation_0-rmse:2.41731	validation_1-rmse:2.97930
# [69]	validation_0-rmse:2.41344	validation_1-rmse:2.97963
# [70]	validation_0-rmse:2.40874	validation_1-rmse:2.98037
# [71]	validation_0-rmse:2.40352	validation_1-rmse:2.98608
# [72]	validation_0-rmse:2.40064	validation_1-rmse:2.98599
# [73]	validation_0-rmse:2.39831	validation_1-rmse:2.98721
# [74]	validation_0-rmse:2.39408	validation_1-rmse:2.98469
# [75]	validation_0-rmse:2.39159	validation_1-rmse:2.98604
# [76]	validation_0-rmse:2.38806	validation_1-rmse:2.98375
# [77]	validation_0-rmse:2.38510	validation_1-rmse:2.98498
# [78]	validation_0-rmse:2.38094	validation_1-rmse:2.98395
# [79]	validation_0-rmse:2.37710	validation_1-rmse:2.98585
# [80]	validation_0-rmse:2.37338	validation_1-rmse:2.98455
# [81]	validation_0-rmse:2.37098	validation_1-rmse:2.98477
# [82]	validation_0-rmse:2.36952	validation_1-rmse:2.98610
# [83]	validation_0-rmse:2.36726	validation_1-rmse:2.98734
# [84]	validation_0-rmse:2.36528	validation_1-rmse:2.98719
# [85]	validation_0-rmse:2.36205	validation_1-rmse:2.98683
# [86]	validation_0-rmse:2.35852	validation_1-rmse:2.98642
# [87]	validation_0-rmse:2.35608	validation_1-rmse:2.98625
# [88]	validation_0-rmse:2.35136	validation_1-rmse:2.98907
# [89]	validation_0-rmse:2.34981	validation_1-rmse:2.98809
# [90]	validation_0-rmse:2.34748	validation_1-rmse:2.98817
# [91]	validation_0-rmse:2.34457	validation_1-rmse:2.98856
# [92]	validation_0-rmse:2.33808	validation_1-rmse:2.98939
# [93]	validation_0-rmse:2.33553	validation_1-rmse:2.99048
# [94]	validation_0-rmse:2.33459	validation_1-rmse:2.98951
# [95]	validation_0-rmse:2.33248	validation_1-rmse:2.98952
# [96]	validation_0-rmse:2.32912	validation_1-rmse:2.99220
# [97]	validation_0-rmse:2.32477	validation_1-rmse:2.99278
# [98]	validation_0-rmse:2.31818	validation_1-rmse:2.99628
# [99]	validation_0-rmse:2.31379	validation_1-rmse:2.99640
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_pred = model.predict(X_test)

plt.scatter(test_df.index, y_pred, label='Validation Data', color='blue', s=1)

# Scatter plot for testing data in another color, e.g., red
plt.scatter(test_df.index, test_df['v'], label='Test Data', color='red', s=1) # s is the size of the marker

# Adding labels and title for clarity
plt.xlabel('Time')
plt.ylabel('v')
plt.title('Validation vs Test Data Scatter Plot')
plt.legend()

# Show plot
plt.show()
