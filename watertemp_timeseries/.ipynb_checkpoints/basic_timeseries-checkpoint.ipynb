# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xgboost as xgb

# %%
def get_dataframe():
    # data = get_historical_water_temp_data_paginated()
    df = pd.read_csv('water_temp_dc_2016_2024_hourly.csv')

    return df


def preprocess(df):
    df['t'] = pd.to_datetime(df['t'])
    df.index = df['t']
    
    df = df[df['v'].notna()]

    return df


def split_train_test(df):
    train_df = df.loc[df.index < '2023-01-01 00:00:00']
    test_df = df.loc[df.index >= '2023-01-01 00:00:00']

    return train_df, test_df


def split_features_target(train_df, test_df, FEATURES, TARGET):
    X_train = train_df[FEATURES]
    y_train = train_df[TARGET]
    
    X_test = test_df[FEATURES]
    y_test = test_df[TARGET]

    return X_train, y_train, X_test, y_test

# %%
df = get_dataframe()
df = preprocess(df)

df['month'] = df.index.month
df['hour'] = df.index.hour

train_df, test_df = split_train_test(df)

FEATURES = ['month', 'hour']
TARGET = 'v'

X_train, y_train, X_test, y_test = split_features_target(train_df, test_df, FEATURES, TARGET)

model = xgb.XGBRegressor()
model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_test, y_test)])
# Out:
# [0]	validation_0-rmse:11.80923	validation_1-rmse:10.69931
# [1]	validation_0-rmse:8.75454	validation_1-rmse:7.64482
# [2]	validation_0-rmse:6.77172	validation_1-rmse:5.69848
# [3]	validation_0-rmse:5.54688	validation_1-rmse:4.55931
# [4]	validation_0-rmse:4.83456	validation_1-rmse:3.97372
# [5]	validation_0-rmse:4.43827	validation_1-rmse:3.71147
# [6]	validation_0-rmse:4.23049	validation_1-rmse:3.62447
# [7]	validation_0-rmse:4.12480	validation_1-rmse:3.61507
# [8]	validation_0-rmse:4.07199	validation_1-rmse:3.63412
# [9]	validation_0-rmse:4.04575	validation_1-rmse:3.66275
# [10]	validation_0-rmse:4.03275	validation_1-rmse:3.68701
# [11]	validation_0-rmse:4.02603	validation_1-rmse:3.70528
# [12]	validation_0-rmse:4.02269	validation_1-rmse:3.72094
# [13]	validation_0-rmse:4.02094	validation_1-rmse:3.73111
# [14]	validation_0-rmse:4.02008	validation_1-rmse:3.73861
# [15]	validation_0-rmse:4.01963	validation_1-rmse:3.74401
# [16]	validation_0-rmse:4.01937	validation_1-rmse:3.74864
# [17]	validation_0-rmse:4.01922	validation_1-rmse:3.75096
# [18]	validation_0-rmse:4.01915	validation_1-rmse:3.75293
# [19]	validation_0-rmse:4.01911	validation_1-rmse:3.75435
# [20]	validation_0-rmse:4.01908	validation_1-rmse:3.75508
# [21]	validation_0-rmse:4.01906	validation_1-rmse:3.75597
# [22]	validation_0-rmse:4.01905	validation_1-rmse:3.75641
# [23]	validation_0-rmse:4.01904	validation_1-rmse:3.75669
# [24]	validation_0-rmse:4.01904	validation_1-rmse:3.75676
# [25]	validation_0-rmse:4.01903	validation_1-rmse:3.75691
# [26]	validation_0-rmse:4.01903	validation_1-rmse:3.75700
# [27]	validation_0-rmse:4.01903	validation_1-rmse:3.75710
# [28]	validation_0-rmse:4.01902	validation_1-rmse:3.75711
# [29]	validation_0-rmse:4.01902	validation_1-rmse:3.75715
# [30]	validation_0-rmse:4.01902	validation_1-rmse:3.75713
# [31]	validation_0-rmse:4.01902	validation_1-rmse:3.75713
# [32]	validation_0-rmse:4.01902	validation_1-rmse:3.75715
# [33]	validation_0-rmse:4.01902	validation_1-rmse:3.75715
# [34]	validation_0-rmse:4.01902	validation_1-rmse:3.75716
# [35]	validation_0-rmse:4.01902	validation_1-rmse:3.75718
# [36]	validation_0-rmse:4.01902	validation_1-rmse:3.75719
# [37]	validation_0-rmse:4.01902	validation_1-rmse:3.75718
# [38]	validation_0-rmse:4.01902	validation_1-rmse:3.75719
# [39]	validation_0-rmse:4.01902	validation_1-rmse:3.75716
# [40]	validation_0-rmse:4.01902	validation_1-rmse:3.75720
# [41]	validation_0-rmse:4.01902	validation_1-rmse:3.75721
# [42]	validation_0-rmse:4.01902	validation_1-rmse:3.75722
# [43]	validation_0-rmse:4.01902	validation_1-rmse:3.75722
# [44]	validation_0-rmse:4.01902	validation_1-rmse:3.75721
# [45]	validation_0-rmse:4.01902	validation_1-rmse:3.75722
# [46]	validation_0-rmse:4.01902	validation_1-rmse:3.75720
# [47]	validation_0-rmse:4.01902	validation_1-rmse:3.75720
# [48]	validation_0-rmse:4.01902	validation_1-rmse:3.75721
# [49]	validation_0-rmse:4.01902	validation_1-rmse:3.75720
# [50]	validation_0-rmse:4.01902	validation_1-rmse:3.75720
# [51]	validation_0-rmse:4.01901	validation_1-rmse:3.75720
# [52]	validation_0-rmse:4.01901	validation_1-rmse:3.75720
# [53]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [54]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [55]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [56]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [57]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [58]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [59]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [60]	validation_0-rmse:4.01901	validation_1-rmse:3.75720
# [61]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [62]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [63]	validation_0-rmse:4.01901	validation_1-rmse:3.75720
# [64]	validation_0-rmse:4.01901	validation_1-rmse:3.75720
# [65]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [66]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [67]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [68]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [69]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [70]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [71]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [72]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [73]	validation_0-rmse:4.01901	validation_1-rmse:3.75722
# [74]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [75]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [76]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [77]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [78]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [79]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [80]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [81]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [82]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [83]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [84]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [85]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [86]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [87]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [88]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [89]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [90]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [91]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [92]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [93]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [94]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [95]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [96]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [97]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [98]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# [99]	validation_0-rmse:4.01901	validation_1-rmse:3.75721
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
# Scatter plot for training data in one color, e.g., blue
plt.scatter(train_df.index, train_df['v'], label='Train Data', color='blue', s=1) # s is the size of the marker

# Scatter plot for testing data in another color, e.g., red
plt.scatter(test_df.index, test_df['v'], label='Test Data', color='red', s=1) # s is the size of the marker

# Adding labels and title for clarity
plt.xlabel('Time')
plt.ylabel('v')
plt.title('Train vs Test Data Scatter Plot')
plt.legend()

# Show plot
plt.show()

# %%
# Step 1: Generate Predictions
y_pred = model.predict(X_test)

plt.scatter(test_df.index, y_pred, label='Validation Data', color='blue', s=1)

# Scatter plot for testing data in another color, e.g., red
plt.scatter(test_df.index, test_df['v'], label='Test Data', color='red', s=1) # s is the size of the marker

# Adding labels and title for clarity
plt.xlabel('Time')
plt.ylabel('v')
plt.title('Validation vs Test Data Scatter Plot')
plt.legend()

# Show plot
plt.show()

# %%
# Step 2: Plot True vs. Predicted Values
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, alpha=0.5, color='red')  # Plotting test vs. predictions
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)  # Diagonal line for reference
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.title('True vs. Predicted Values')

# Optionally, add a trend line (commented out)
# z = np.polyfit(y_test, y_pred, 1)
# p = np.poly1d(z)
# plt.plot(y_test,p(y_test),"r--")

plt.show()

# %%
df = get_dataframe()
df = preprocess(df)

df['month'] = df.index.month
df['hour'] = df.index.hour
df['day'] = df.index.day

train_df, test_df = split_train_test(df)

FEATURES = ['month', 'hour', 'day']
TARGET = 'v'

X_train, y_train, X_test, y_test = split_features_target(train_df, test_df, FEATURES, TARGET)

model = xgb.XGBRegressor()
model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_test, y_test)])
# Out:
# [0]	validation_0-rmse:11.67742	validation_1-rmse:10.57768
# [1]	validation_0-rmse:8.48326	validation_1-rmse:7.37698
# [2]	validation_0-rmse:6.35183	validation_1-rmse:5.27748
# [3]	validation_0-rmse:4.98283	validation_1-rmse:3.97260
# [4]	validation_0-rmse:4.14600	validation_1-rmse:3.28093
# [5]	validation_0-rmse:3.64815	validation_1-rmse:2.94172
# [6]	validation_0-rmse:3.38218	validation_1-rmse:2.83213
# [7]	validation_0-rmse:3.23333	validation_1-rmse:2.81630
# [8]	validation_0-rmse:3.15408	validation_1-rmse:2.83813
# [9]	validation_0-rmse:3.11329	validation_1-rmse:2.86268
# [10]	validation_0-rmse:3.08834	validation_1-rmse:2.89698
# [11]	validation_0-rmse:3.07209	validation_1-rmse:2.90417
# [12]	validation_0-rmse:3.06501	validation_1-rmse:2.92215
# [13]	validation_0-rmse:3.06003	validation_1-rmse:2.93155
# [14]	validation_0-rmse:3.05725	validation_1-rmse:2.94020
# [15]	validation_0-rmse:3.05583	validation_1-rmse:2.94651
# [16]	validation_0-rmse:3.05308	validation_1-rmse:2.95025
# [17]	validation_0-rmse:3.05231	validation_1-rmse:2.95297
# [18]	validation_0-rmse:3.05184	validation_1-rmse:2.95521
# [19]	validation_0-rmse:3.04962	validation_1-rmse:2.95813
# [20]	validation_0-rmse:3.04886	validation_1-rmse:2.96081
# [21]	validation_0-rmse:3.04865	validation_1-rmse:2.96135
# [22]	validation_0-rmse:3.04704	validation_1-rmse:2.96548
# [23]	validation_0-rmse:3.04686	validation_1-rmse:2.96647
# [24]	validation_0-rmse:3.04651	validation_1-rmse:2.96853
# [25]	validation_0-rmse:3.04584	validation_1-rmse:2.97010
# [26]	validation_0-rmse:3.04560	validation_1-rmse:2.97045
# [27]	validation_0-rmse:3.04544	validation_1-rmse:2.97125
# [28]	validation_0-rmse:3.04533	validation_1-rmse:2.97165
# [29]	validation_0-rmse:3.04523	validation_1-rmse:2.97200
# [30]	validation_0-rmse:3.04511	validation_1-rmse:2.97252
# [31]	validation_0-rmse:3.04499	validation_1-rmse:2.97279
# [32]	validation_0-rmse:3.04485	validation_1-rmse:2.97238
# [33]	validation_0-rmse:3.04459	validation_1-rmse:2.97490
# [34]	validation_0-rmse:3.04441	validation_1-rmse:2.97654
# [35]	validation_0-rmse:3.04418	validation_1-rmse:2.97813
# [36]	validation_0-rmse:3.04414	validation_1-rmse:2.97794
# [37]	validation_0-rmse:3.04403	validation_1-rmse:2.97819
# [38]	validation_0-rmse:3.04389	validation_1-rmse:2.97814
# [39]	validation_0-rmse:3.04382	validation_1-rmse:2.97819
# [40]	validation_0-rmse:3.04374	validation_1-rmse:2.97877
# [41]	validation_0-rmse:3.04365	validation_1-rmse:2.97843
# [42]	validation_0-rmse:3.04360	validation_1-rmse:2.97837
# [43]	validation_0-rmse:3.04357	validation_1-rmse:2.97842
# [44]	validation_0-rmse:3.04349	validation_1-rmse:2.97908
# [45]	validation_0-rmse:3.04333	validation_1-rmse:2.98008
# [46]	validation_0-rmse:3.04328	validation_1-rmse:2.98010
# [47]	validation_0-rmse:3.04325	validation_1-rmse:2.98017
# [48]	validation_0-rmse:3.04320	validation_1-rmse:2.98004
# [49]	validation_0-rmse:3.04307	validation_1-rmse:2.97987
# [50]	validation_0-rmse:3.04295	validation_1-rmse:2.98019
# [51]	validation_0-rmse:3.04292	validation_1-rmse:2.98047
# [52]	validation_0-rmse:3.04289	validation_1-rmse:2.98071
# [53]	validation_0-rmse:3.04282	validation_1-rmse:2.98081
# [54]	validation_0-rmse:3.04274	validation_1-rmse:2.98087
# [55]	validation_0-rmse:3.04268	validation_1-rmse:2.98131
# [56]	validation_0-rmse:3.04264	validation_1-rmse:2.98091
# [57]	validation_0-rmse:3.04257	validation_1-rmse:2.98144
# [58]	validation_0-rmse:3.04253	validation_1-rmse:2.98149
# [59]	validation_0-rmse:3.04250	validation_1-rmse:2.98124
# [60]	validation_0-rmse:3.04248	validation_1-rmse:2.98108
# [61]	validation_0-rmse:3.04246	validation_1-rmse:2.98112
# [62]	validation_0-rmse:3.04242	validation_1-rmse:2.98106
# [63]	validation_0-rmse:3.04239	validation_1-rmse:2.98101
# [64]	validation_0-rmse:3.04236	validation_1-rmse:2.98136
# [65]	validation_0-rmse:3.04234	validation_1-rmse:2.98148
# [66]	validation_0-rmse:3.04231	validation_1-rmse:2.98155
# [67]	validation_0-rmse:3.04229	validation_1-rmse:2.98168
# [68]	validation_0-rmse:3.04224	validation_1-rmse:2.98189
# [69]	validation_0-rmse:3.04222	validation_1-rmse:2.98195
# [70]	validation_0-rmse:3.04217	validation_1-rmse:2.98224
# [71]	validation_0-rmse:3.04215	validation_1-rmse:2.98239
# [72]	validation_0-rmse:3.04212	validation_1-rmse:2.98214
# [73]	validation_0-rmse:3.04210	validation_1-rmse:2.98221
# [74]	validation_0-rmse:3.04207	validation_1-rmse:2.98225
# [75]	validation_0-rmse:3.04203	validation_1-rmse:2.98235
# [76]	validation_0-rmse:3.04201	validation_1-rmse:2.98271
# [77]	validation_0-rmse:3.04199	validation_1-rmse:2.98283
# [78]	validation_0-rmse:3.04196	validation_1-rmse:2.98285
# [79]	validation_0-rmse:3.04194	validation_1-rmse:2.98290
# [80]	validation_0-rmse:3.04193	validation_1-rmse:2.98311
# [81]	validation_0-rmse:3.04192	validation_1-rmse:2.98317
# [82]	validation_0-rmse:3.04189	validation_1-rmse:2.98304
# [83]	validation_0-rmse:3.04186	validation_1-rmse:2.98297
# [84]	validation_0-rmse:3.04184	validation_1-rmse:2.98302
# [85]	validation_0-rmse:3.04181	validation_1-rmse:2.98312
# [86]	validation_0-rmse:3.04178	validation_1-rmse:2.98321
# [87]	validation_0-rmse:3.04176	validation_1-rmse:2.98313
# [88]	validation_0-rmse:3.04173	validation_1-rmse:2.98310
# [89]	validation_0-rmse:3.04171	validation_1-rmse:2.98319
# [90]	validation_0-rmse:3.04170	validation_1-rmse:2.98308
# [91]	validation_0-rmse:3.04168	validation_1-rmse:2.98310
# [92]	validation_0-rmse:3.04166	validation_1-rmse:2.98315
# [93]	validation_0-rmse:3.04165	validation_1-rmse:2.98326
# [94]	validation_0-rmse:3.04162	validation_1-rmse:2.98338
# [95]	validation_0-rmse:3.04161	validation_1-rmse:2.98332
# [96]	validation_0-rmse:3.04159	validation_1-rmse:2.98337
# [97]	validation_0-rmse:3.04158	validation_1-rmse:2.98344
# [98]	validation_0-rmse:3.04156	validation_1-rmse:2.98361
# [99]	validation_0-rmse:3.04154	validation_1-rmse:2.98363
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
# Step 1: Generate Predictions
y_pred = model.predict(X_test)

plt.scatter(test_df.index, y_pred, label='Validation Data', color='blue', s=1)

# Scatter plot for testing data in another color, e.g., red
plt.scatter(test_df.index, test_df['v'], label='Test Data', color='red', s=1) # s is the size of the marker

# Adding labels and title for clarity
plt.xlabel('Time')
plt.ylabel('v')
plt.title('Validation vs Test Data Scatter Plot')
plt.legend()

# Show plot
plt.show()
